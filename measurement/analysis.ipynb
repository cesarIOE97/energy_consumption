# %% [markdown]
# # Analysis for Performance and Energy Consumption

# %% [markdown]
# ## Extract information

# %%
# Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the CSV data into a DataFrame
data = pd.read_csv('nbody_50000/performance_data_allVersions_nbody.csv')
data
# Out:
#      python_version    appplication  time_elapsed    usec  \
# 0      Python 2.5.6  nbody.py 50000      0.532964  1398.4
# 1     Python 2.7.18  nbody.py 50000      0.439228  1205.8
# 2      Python 3.0.1  nbody.py 50000      0.558969  1291.8
# 3     Python 3.4.10  nbody.py 50000      0.498479  1201.5
# 4     Python 3.5.10  nbody.py 50000      0.487546  1201.4
# 5     Python 3.6.15  nbody.py 50000      0.491156  1152.2
# 6     Python 3.7.16  nbody.py 50000      0.463402  1196.6
# 7     Python 3.8.16  nbody.py 50000      0.535775  1254.7
# 8     Python 3.9.16  nbody.py 50000      0.523530  1264.9
# 9    Python 3.10.11  nbody.py 50000      0.528200  1149.1
# 10    Python 3.11.3  nbody.py 50000      0.314730  1192.2
# 11  Python 3.12.0b1  nbody.py 50000      0.324578  1112.1
# 12  Python 3.13.0a0  nbody.py 50000      0.329215  1134.0
#
#     Time_Of_Day_Seconds  APIC  X2APIC  Avg_MHz  Busy%  Bzy_MHz  ...  Pkg%pc9  \
# 0          1.686119e+09     0       0    676.3  19.51   3766.9  ...        0
# 1          1.686119e+09     0       0    714.7  18.55   3891.7  ...        0
# 2          1.686119e+09     0       0    676.1  17.22   3937.9  ...        0
# 3          1.686119e+09     0       0    696.3  19.58   3724.8  ...        0
# 4          1.686119e+09     0       0    693.7  18.56   3836.3  ...        0
# 5          1.686119e+09     0       0    697.7  19.96   3703.3  ...        0
# 6          1.686119e+09     0       0    705.5  19.31   3815.6  ...        0
# 7          1.686119e+09     0       0    676.1  20.70   3470.8  ...        0
# 8          1.686120e+09     0       0    671.4  18.61   3713.8  ...        0
# 9          1.686120e+09     0       0    686.4  18.06   3859.7  ...        0
# 10         1.686120e+09     0       0    769.4  22.68   3648.0  ...        0
# 11         1.686132e+09     0       0    902.9  23.00   3930.0  ...        0
# 12         1.686132e+09     0       0    806.6  20.44   3951.8  ...        0
#
#     Pk%pc10  CPU%LPI  SYS%LPI  Pkg_J  Cor_J  GFX_J  RAM_J  PKG_%  RAM_%
# 0         0        0        0   9.95   8.73   0.02   0.28      0      0
# 1         0        0        0   8.72   7.66   0.03   0.26      0      0
# 2         0        0        0  10.57   9.27   0.03   0.30      0      0
# 3         0        0        0   9.72   8.54   0.02   0.28      0      0
# 4         0        0        0   9.57   8.40   0.03   0.27      0      0
# 5         0        0        0   9.44   8.26   0.03   0.28      0      0
# 6         0        0        0   9.05   7.94   0.02   0.27      0      0
# 7         0        0        0  10.18   8.89   0.03   0.29      0      0
# 8         0        0        0   9.89   8.66   0.02   0.28      0      0
# 9         0        0        0  10.18   8.91   0.03   0.29      0      0
# 10        0        0        0   6.28   5.46   0.03   0.22      0      0
# 11        0        0        0   7.50   6.54   0.03   0.31      0      0
# 12        0        0        0   7.09   6.14   0.02   0.30      0      0
#
# [13 rows x 60 columns]

# %%
# Extract relevant columns
python_version = data['python_version']
time_elapsed = data['time_elapsed']
energy_pkg = data['Pkg_J']
avg_mhz = data['Avg_MHz']

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Time elapsed vs CPU usage

# %%
# Plot time elapsed vs CPU usage
plt.figure(figsize=(8, 6))
plt.scatter(time_elapsed, energy_pkg)
plt.xlabel('Time Elapsed')
plt.ylabel('Energy Pkg')
plt.title('Time Elapsed vs Pkg_J')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Plot time elapsed vs Memory usage
plt.figure(figsize=(8, 6))
plt.scatter(time_elapsed, avg_mhz)
plt.xlabel('Time Elapsed')
plt.ylabel('Avg MHz')
plt.title('Time Elapsed vs Avg MHz')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Plot Python version vs Energy Consumption
plt.figure(figsize=(8,6))
plt.plot(python_version, energy_pkg)
plt.xlabel('Python version')
plt.ylabel('Energy Pkg')
plt.xticks(rotation=45)
plt.title('Python versions vs Energy Pkg')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Plot Python version vs Time elipsed
plt.figure(figsize=(8,6))
plt.plot(python_version, time_elapsed)
plt.xlabel('Python version')
plt.ylabel('Time Elapsed')
plt.xticks(rotation=45)
plt.title('Python versions vs Time Elapsed')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
g = sns.pairplot(data)
g.fig.suptitle(f"Pair plot of ")
plt.show()

# %%
# Normalize the data
# Observe the correlation between the values
# Select which parameters
# Find information regarding the memory consumption/usage
# Select algorithms/application
